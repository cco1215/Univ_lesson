# %%
import pandas as pd

# %%
rawdf =  pd.read_csv('C:/jupiterr/owid-covid-data.csv')

# %%
raw_hawaii_df = pd.read_csv('C:/jupiterr/owid-covid-data.csv')

# %%
rawdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192301 entries, 0 to 192300
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    192301 non-null  object
#  1   continent                                   181123 non-null  object
#  2   location                                    192301 non-null  object
#  3   date                                        192301 non-null  object
#  4   total_cases                                 184750 non-null  float64
#  5   new_cases                                   184508 non-null  float64
#  6   new_cases_smoothed                          183334 non-null  float64
#  7   total_deaths                                166260 non-null  float64
#  8   new_deaths                                  166241 non-null  float64
# ...

# %%
select_colums = ['iso_code', 'location','date','total_cases','population']

reviseddf = rawdf[select_colums]

reviseddf.head()
# Out:
#   iso_code     location        date  total_cases  population
# 0      AFG  Afghanistan  2020-02-24          5.0  39835428.0
# 1      AFG  Afghanistan  2020-02-25          5.0  39835428.0
# 2      AFG  Afghanistan  2020-02-26          5.0  39835428.0
# 3      AFG  Afghanistan  2020-02-27          5.0  39835428.0
# 4      AFG  Afghanistan  2020-02-28          5.0  39835428.0

# %%
location = reviseddf['location']
location
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 192296       Zimbabwe
# 192297       Zimbabwe
# 192298       Zimbabwe
# 192299       Zimbabwe
# 192300       Zimbabwe
# Name: location, Length: 192301, dtype: object

# %%
location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
kordf = reviseddf[reviseddf.location == 'South Korea']
kordf.head()
# Out:
#        iso_code     location        date  total_cases  population
# 160818      KOR  South Korea  2020-01-22          1.0  51305184.0
# 160819      KOR  South Korea  2020-01-23          1.0  51305184.0
# 160820      KOR  South Korea  2020-01-24          2.0  51305184.0
# 160821      KOR  South Korea  2020-01-25          2.0  51305184.0
# 160822      KOR  South Korea  2020-01-26          3.0  51305184.0

# %%
kor_date_index_of = kordf.set_index('date')

kor_date_index_of.head()
# Out:
#            iso_code     location  total_cases  population
# date
# 2020-01-22      KOR  South Korea          1.0  51305184.0
# 2020-01-23      KOR  South Korea          1.0  51305184.0
# 2020-01-24      KOR  South Korea          2.0  51305184.0
# 2020-01-25      KOR  South Korea          2.0  51305184.0
# 2020-01-26      KOR  South Korea          3.0  51305184.0

# %%
usadf = reviseddf[reviseddf.location == 'United States']

usa_date_index_of = usadf.set_index('date')

usa_date_index_of.head()
# Out:
#            iso_code       location  total_cases   population
# date
# 2020-01-22      USA  United States          1.0  332915074.0
# 2020-01-23      USA  United States          1.0  332915074.0
# 2020-01-24      USA  United States          2.0  332915074.0
# 2020-01-25      USA  United States          2.0  332915074.0
# 2020-01-26      USA  United States          5.0  332915074.0

# %%
kor_total_cases = kor_date_index_of['total_cases']
kor_total_cases
# Out:
# date
# 2020-01-22           1.0
# 2020-01-23           1.0
# 2020-01-24           2.0
# 2020-01-25           2.0
# 2020-01-26           3.0
#                  ...
# 2022-06-03    18153851.0
# 2022-06-04    18163686.0
# 2022-06-05    18168708.0
# 2022-06-06    18174880.0
# 2022-06-07    18188200.0
# Name: total_cases, Length: 868, dtype: float64

# %%
usa_total_cases = usa_date_index_of['total_cases']
usa_total_cases
# Out:
# date
# 2020-01-22           1.0
# 2020-01-23           1.0
# 2020-01-24           2.0
# 2020-01-25           2.0
# 2020-01-26           5.0
#                  ...
# 2022-06-03    84724329.0
# 2022-06-04    84748884.0
# 2022-06-05    84762022.0
# 2022-06-06    84882287.0
# 2022-06-07    85003945.0
# Name: total_cases, Length: 868, dtype: float64

# %%
kor_date_index_of.index
# Out:
# Index(['2020-01-22', '2020-01-23', '2020-01-24', '2020-01-25', '2020-01-26',
#        '2020-01-27', '2020-01-28', '2020-01-29', '2020-01-30', '2020-01-31',
#        ...
#        '2022-05-29', '2022-05-30', '2022-05-31', '2022-06-01', '2022-06-02',
#        '2022-06-03', '2022-06-04', '2022-06-05', '2022-06-06', '2022-06-07'],
#       dtype='object', name='date', length=868)

# %%
finaldf = pd.concat([kor_date_index_of, usa_date_index_of], keys=["KOR", "USA"])

finaldf.head()
# Out:
#                iso_code     location  total_cases  population
#     date
# KOR 2020-01-22      KOR  South Korea          1.0  51305184.0
#     2020-01-23      KOR  South Korea          1.0  51305184.0
#     2020-01-24      KOR  South Korea          2.0  51305184.0
#     2020-01-25      KOR  South Korea          2.0  51305184.0
#     2020-01-26      KOR  South Korea          3.0  51305184.0

# %%
finaldf['2022-01-01':].plot.line()
# Out:
# <Axes: xlabel='None,date'>

# %%
kor_population = kor_date_index_of['population']['2022-01-01']

usa_population = usa_date_index_of['population']['2022-01-01']

print("미국인구(", usa_population, ") / 대한민국 인구(", kor_population, ") = ", usa_population/kor_population)
# Out:
# 미국인구( 332915074.0 ) / 대한민국 인구( 51305184.0 ) =  6.488916870466735

# %%
usa_rate = round((usa_population / kor_population), 2)

# %%
final_revised_df = pd.DataFrame({'KOR' : kor_total_cases, 'USA' : usa_total_cases}, index=kor_date_index_of.index)

final_revised_df.head()
# Out:
#             KOR  USA
# date
# 2020-01-22  1.0  1.0
# 2020-01-23  1.0  1.0
# 2020-01-24  2.0  2.0
# 2020-01-25  2.0  2.0
# 2020-01-26  3.0  5.0

# %%
final_revised_df[:].plot.line()
# Out:
# <Axes: xlabel='date'>

# %%
final_revised_df['2022-01-01':].plot.line(rot=45)
# Out:
# <Axes: xlabel='date'>

# %%
fra_df = reviseddf[reviseddf.location == 'France']

fra_date_index_df = fra_df.set_index('date')

fra_total_cases = fra_date_index_df['total_cases']

fra_population = fra_date_index_df['population']['2022-01-01']

fra_rate = round((fra_population / kor_population), 2)

final_revised_df = pd.DataFrame({'KOR' : kor_total_cases * fra_rate, 'FRA' : fra_total_cases}, index=kor_date_index_of.index)

final_revised_df[:].plot.line()
# Out:
# <Axes: xlabel='date'>

# %%
gbr_df = reviseddf[reviseddf.location == 'United Kingdom']

gbr_date_index_df = gbr_df.set_index('date')

gbr_total_cases = gbr_date_index_df['total_cases']

gbr_population = gbr_date_index_df['population']['2022-01-01']

gbr_rate = round((gbr_population / kor_population), 2)

# %%
pol_df = reviseddf[reviseddf.location == 'Poland']

pol_date_index_df = pol_df.set_index('date')

pol_total_cases = pol_date_index_df['total_cases']

pol_population = pol_date_index_df['population']['2022-01-01']

pol_rate = round((pol_population / kor_population), 2)

# %%
raw_hawaii_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192301 entries, 0 to 192300
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    192301 non-null  object
#  1   continent                                   181123 non-null  object
#  2   location                                    192301 non-null  object
#  3   date                                        192301 non-null  object
#  4   total_cases                                 184750 non-null  float64
#  5   new_cases                                   184508 non-null  float64
#  6   new_cases_smoothed                          183334 non-null  float64
#  7   total_deaths                                166260 non-null  float64
#  8   new_deaths                                  166241 non-null  float64
# ...

# %%
raw_hawaii_df = pd.read_csv('C:/jupiterr/hawaii-covid-data.csv')

raw_hawaii_df.head()
# Out:
#   submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0      10/26/2021    HI      80876         NaN         NaN        69
# 1      06/17/2021    HI      35862         NaN         NaN        31
# 2      12/30/2021    HI     106350         NaN         NaN      3425
# 3      11/12/2020    HI      16171         NaN         NaN        94
# 4      06/15/2021    HI      35802         NaN         NaN        33
#
#    pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 0       10.0        883         NaN         NaN          0         0.0
# 1        0.0        504         NaN         NaN          0         0.0
# 2      368.0       1074         NaN         NaN          0         0.0
# 3        0.0        221         NaN         NaN          0         0.0
# 4        5.0        503         NaN         NaN          0         0.0
#
#                created_at consent_cases consent_deaths
# 0  10/27/2021 02:21:35 PM     Not agree      Not agree
# ...

# %%
filtered_hawaii_df = raw_hawaii_df[['submission_date', 'tot_cases']]
filtered_hawaii_df.head()
# Out:
#   submission_date  tot_cases
# 0      10/26/2021      80876
# 1      06/17/2021      35862
# 2      12/30/2021     106350
# 3      11/12/2020      16171
# 4      06/15/2021      35802

# %%
sorted_hawaii_df = filtered_hawaii_df.sort_values(by='submission_date')
sorted_hawaii_df
# Out:
#     submission_date  tot_cases
# 480      01/01/2021      21258
# 726      01/01/2022     112283
# 371      01/02/2021      21417
# 300      01/02/2022     115400
# 507      01/03/2021      21539
# ..              ...        ...
# 40       12/29/2021     102925
# 842      12/30/2020      20851
# 2        12/30/2021     106350
# 361      12/31/2020      21026
# 733      12/31/2021     109576
#
# [912 rows x 2 columns]

# %%
sorted_hawaii_df['date'] = pd.to_datetime(sorted_hawaii_df['submission_date'])
sorted_hawaii_df.head()
# Out:
#     submission_date  tot_cases       date
# 480      01/01/2021      21258 2021-01-01
# 726      01/01/2022     112283 2022-01-01
# 371      01/02/2021      21417 2021-01-02
# 300      01/02/2022     115400 2022-01-02
# 507      01/03/2021      21539 2021-01-03

# %%
sorted_hawaii_df.sort_values(by='date', inplace=True)
sorted_hawaii_df
# Out:
#     submission_date  tot_cases       date
# 617      01/22/2020          0 2020-01-22
# 91       01/23/2020          0 2020-01-23
# 797      01/24/2020          0 2020-01-24
# 466      01/25/2020          0 2020-01-25
# 396      01/26/2020          0 2020-01-26
# ..              ...        ...        ...
# 29       07/17/2022     309561 2022-07-17
# 168      07/18/2022     309561 2022-07-18
# 669      07/19/2022     309561 2022-07-19
# 455      07/20/2022     313805 2022-07-20
# 16       07/21/2022     313805 2022-07-21
#
# [912 rows x 3 columns]

# %%
sorted_hawaii_df.set_index('date', inplace=True)
sorted_hawaii_df.head()
# Out:
#            submission_date  tot_cases
# date
# 2020-01-22      01/22/2020          0
# 2020-01-23      01/23/2020          0
# 2020-01-24      01/24/2020          0
# 2020-01-25      01/25/2020          0
# 2020-01-26      01/26/2020          0

# %%
hawaii_total_cases = sorted_hawaii_df['tot_cases']
hawaii_total_cases
# Out:
# date
# 2020-01-22         0
# 2020-01-23         0
# 2020-01-24         0
# 2020-01-25         0
# 2020-01-26         0
#                ...
# 2022-07-17    309561
# 2022-07-18    309561
# 2022-07-19    309561
# 2022-07-20    313805
# 2022-07-21    313805
# Name: tot_cases, Length: 912, dtype: int64

# %%
hawaii_population = 1_455_271
hawaii_rate = round((hawaii_population / kor_population), 2)
hawaii_rate
# Out:
# np.float64(0.03)

# %%
final_hawaii_revised_df = pd.DataFrame({'KOR' : kor_total_cases * hawaii_rate,
                                        'HAW' : hawaii_total_cases},
                                       index=kor_date_index_of.index)
final_hawaii_revised_df
# Out:
#                   KOR     HAW
# date
# 2020-01-22       0.03       0
# 2020-01-23       0.03       0
# 2020-01-24       0.06       0
# 2020-01-25       0.06       0
# 2020-01-26       0.09       0
# ...               ...     ...
# 2022-06-03  544615.53  275631
# 2022-06-04  544910.58  275631
# 2022-06-05  545061.24  275631
# 2022-06-06  545246.40  275631
# 2022-06-07  545646.00  275631
#
# [868 rows x 2 columns]

# %%
final_hawaii_revised_df.plot.line()
# Out:
# <Axes: xlabel='date'>

# %%
final_hawaii_revised_df['2022-01-01':].plot.line(rot=45)
# Out:
# <Axes: xlabel='date'>

# %%
haw_usa_rate = round((hawaii_population / usa_population * 100), 2)
haw_usa_rate
# Out:
# np.float64(0.44)

# %%
fianl_hawaii_usa_kor_df = pd.DataFrame({'KOR' : kor_total_cases * hawaii_rate,
                                        'USA' : usa_total_cases * haw_usa_rate / 100,
                                        'HAW' : hawaii_total_cases},
                                       index=kor_date_index_of.index)
fianl_hawaii_usa_kor_df['2022-01-01':'2022-06-25'].plot.line(rot = 45)
# Out:
# <Axes: xlabel='date'>

# %%
haw_usa_rate
# Out:
# np.float64(0.44)

# %%
raw_state_df = pd.read_csv('C:/jupiterr/states-covid-data.csv')
raw_state_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4560 entries, 0 to 4559
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   submission_date  4560 non-null   object
#  1   state            4560 non-null   object
#  2   tot_cases        4560 non-null   int64
#  3   conf_cases       2561 non-null   float64
#  4   prob_cases       2561 non-null   float64
#  5   new_case         4560 non-null   int64
#  6   pnew_case        4343 non-null   float64
#  7   tot_death        4560 non-null   int64
#  8   conf_death       2283 non-null   float64
#  9   prob_death       2283 non-null   float64
#  10  new_death        4560 non-null   int64
#  11  pnew_death       4343 non-null   float64
#  12  created_at       4560 non-null   object
#  13  consent_cases    3648 non-null   object
#  14  consent_deaths   3648 non-null   object
# dtypes: float64(6), int64(4), object(5)
# memory usage: 534.5+ KB

# %%
raw_state_df['date'] = pd.to_datetime(raw_state_df['submission_date'])
raw_state_df.sort_values(by='date', inplace=True)
raw_state_df
# Out:
#      submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 2077      01/22/2020    TX          0         NaN         NaN         0
# 1458      01/22/2020    VA          0         NaN         NaN         0
# 2978      01/22/2020    WA          0         NaN         NaN         0
# 242       01/22/2020    CA          0         0.0         0.0         0
# 314       01/22/2020    IL          0         NaN         NaN         0
# ...              ...   ...        ...         ...         ...       ...
# 1299      07/21/2022    IL    3523006   3523006.0         0.0      6636
# 3167      07/21/2022    CA   10495155   9752509.0    742646.0         0
# 3917      07/21/2022    WA    1717051         NaN         NaN      3203
# 1435      07/21/2022    VA    1933366   1377097.0    556269.0      3648
# 2038      07/21/2022    TX    7338125         NaN         NaN     12716
#
#       pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# ...

# %%
raw_state_df.set_index('date', inplace=True)
raw_state_df.head()
# Out:
#            submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# date
# 2020-01-22      01/22/2020    TX          0         NaN         NaN         0
# 2020-01-22      01/22/2020    VA          0         NaN         NaN         0
# 2020-01-22      01/22/2020    WA          0         NaN         NaN         0
# 2020-01-22      01/22/2020    CA          0         0.0         0.0         0
# 2020-01-22      01/22/2020    IL          0         NaN         NaN         0
#
#             pnew_case  tot_death  conf_death  prob_death  new_death  \
# date
# 2020-01-22        NaN          0         NaN         NaN          0
# 2020-01-22        NaN          0         NaN         NaN          0
# 2020-01-22        0.0          0         NaN         NaN          0
# 2020-01-22        0.0          0         NaN         NaN          0
# 2020-01-22        NaN          0         NaN         NaN          0
#
# ...

# %%
ca_population = 39_995_077
tx_population = 29_945_493
va_population = 8_757_467
il_population = 12_808_884
wa_population = 7_901_429

# %%
tx_rate = round((ca_population / tx_population), 2)
va_rate = round((ca_population / va_population), 2)
il_rate = round((ca_population / il_population), 2)
wa_rate = round((ca_population / wa_population), 2)

# %%
ca_total_cases = raw_state_df[raw_state_df.location == 'Ca']['total_cases']
tx_total_cases = raw_state_df[raw_state_df.location == 'Tx']['total_cases']
va_total_cases = raw_state_df[raw_state_df.location == 'Va']['total_cases']
il_total_cases = raw_state_df[raw_state_df.location == 'Il']['total_cases']
wa_total_cases = raw_state_df[raw_state_df.location == 'Wa']['total_cases']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 ca_total_cases = raw_state_df[raw_state_df.location == 'Ca']['total_cases']
#       2 tx_total_cases = raw_state_df[raw_state_df.location == 'Tx']['total_cases']
#       3 va_total_cases = raw_state_df[raw_state_df.location == 'Va']['total_cases']
#
# File c:\Users\cco1215\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'location'

# %%
tx_rate = round((ca_population / tx_population), 2)
va_rate = round((ca_population / va_population), 2)
il_rate = round((ca_population / il_population), 2)
wa_rate = round((ca_population / wa_population), 2)

final_hawaii_usa_kor_df = pd.DataFrame({'CA' : usa_total_cases,
                                        'TX' : usa_total_cases * tx_rate,
                                        'VA' : usa_total_cases * va_rate,
                                        'IL' : usa_total_cases * il_rate,
                                        'WA' : usa_total_cases * wa_rate},
                                       index=sorted_hawaii_df.index)
final_hawaii_usa_kor_df['2022-01-01':].plot.line(rot = 45)
# Out:
# <Axes: xlabel='date'>
